# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('THB.csv')

# %%
df.values[:,1]
# Out:
# array([32.98, 32.89, 32.99, ..., 30.73, 30.695, 30.77], dtype=object)

# %%
bath = df.values[:,1]
plt.plot(np.arange(len(bath)), bath)
